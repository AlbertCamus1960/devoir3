# %%
import pandas as pan
pan.set_option("display.float_format", lambda x : "%.2f" % x)
import matplotlib as mp
# %matplotlib inline

# %%
acces = pan.read_csv("donnees/ati".csv)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-9b029c61c4f1> in <module>()
# ----> 1 acces = pan.read_csv("donnees/ati".csv)
#
# AttributeError: 'str' object has no attribute 'csv'

# %%
acces = pan.read_csv("donnees/ati.csv")

# %%
acces
# Out:
#        year  month request_number  \
# 0      2017      5   A-2016-00059
# 1      2016      7   A-2016-00076
# 2      2016      7   A-2016-00071
# 3      2017      7   A-2017-00063
# 4      2016     10   A-2016-00121
# 5      2016      7   A-2016-00072
# 6      2016      6   A-2016-00026
# 7      2016      7   A-2016-00077
# 8      2016      6   A-2016-00061
# 9      2016      6   A-2016-00038
# 10     2016      6   A-2016-00027
# 11     2016      8   A-2016-00088
# 12     2016      6   A-2016-00024
# 13     2016      6   A-2016-00021
# 14     2016      6   A-2016-00017
# 15     2016      6   A-2016-00014
# 16     2016      6   A-2016-00012
# 17     2016      6   A-2015-00110
# 18     2016      6   A-2015-00104
# 19     2016      6   A-2015-00102
# 20     2016      6   A-2015-00083
# 21     2016      6   A-2014-00158
# 22     2016      6   A-2014-00157
# 23     2016      6   A-2014-00156
# 24     2016      7   A-2016-00082
# 25     2016      7   A-2016-00078
# ...

# %%
acces.head
# Out:
# <bound method NDFrame.head of        year  month request_number  \
# 0      2017      5   A-2016-00059
# 1      2016      7   A-2016-00076
# 2      2016      7   A-2016-00071
# 3      2017      7   A-2017-00063
# 4      2016     10   A-2016-00121
# 5      2016      7   A-2016-00072
# 6      2016      6   A-2016-00026
# 7      2016      7   A-2016-00077
# 8      2016      6   A-2016-00061
# 9      2016      6   A-2016-00038
# 10     2016      6   A-2016-00027
# 11     2016      8   A-2016-00088
# 12     2016      6   A-2016-00024
# 13     2016      6   A-2016-00021
# 14     2016      6   A-2016-00017
# 15     2016      6   A-2016-00014
# 16     2016      6   A-2016-00012
# 17     2016      6   A-2015-00110
# 18     2016      6   A-2015-00104
# 19     2016      6   A-2015-00102
# 20     2016      6   A-2015-00083
# 21     2016      6   A-2014-00158
# 22     2016      6   A-2014-00157
# 23     2016      6   A-2014-00156
# 24     2016      7   A-2016-00082
# ...

# %%
acces.head()
# Out:
#    year  month request_number  \
# 0  2017      5   A-2016-00059
# 1  2016      7   A-2016-00076
# 2  2016      7   A-2016-00071
# 3  2017      7   A-2017-00063
# 4  2016     10   A-2016-00121
#
#                                           summary_en  \
# 0  All communications between the AgriMarketing P...
# 1  The amount of funding provided to National Far...
# 2  The amount of funding provided to National Far...
# 3  Copy of the briefing note (#226947) UPDATE ON ...
# 4  Please provide copies of the tobacco farming d...
#
#                                           summary_fr  \
# 0  Toutes les communications entre le programme A...
# 1  Le montant du financement octroyé au Conseil n...
# 2  Le montant du financement octroyé au Conseil n...
# 3  Copie de la note d'information (# 226947) MISE...
# 4  Veuillez fournir des copies des estimations de...
#
#                                      disposition  pages owner_org  \
# ...

# %%
acces.dtypes
# Out:
# year                 int64
# month                int64
# request_number      object
# summary_en          object
# summary_fr          object
# disposition         object
# pages              float64
# owner_org           object
# owner_org_title     object
# dtype: object

# %%
acces.describe()
# Out:
#           year    month     pages
# count 28492.00 28492.00  28442.00
# mean   2016.79     6.63    242.97
# std       0.64     3.48   7027.25
# min    2016.00     0.00      0.00
# 25%    2016.00     3.00      1.00
# 50%    2017.00     7.00     11.00
# 75%    2017.00    10.00     70.00
# max    2018.00    66.00 774731.00

# %%
acces.year.value_counts()
# le nombre de demandes par année
# Out:
# 2017    15360
# 2016     9620
# 2018     3512
# Name: year, dtype: int64

# %%
acces.owner_org.value_counts()
# le nombre de demandes pour les différentes organisations. La numéro 1 est la défense nationale.
# Out:
# dnd-mdn         2518
# dfatd-maecd     1707
# cic             1376
# esdc-edsc       1330
# ic              1257
# pco-bcp         1255
# nrcan-rncan     1215
# fin             1173
# hc-sc           1119
# lac-bac         1050
# cra-arc          874
# cbsa-asfc        854
# ec               845
# jus              797
# pch              789
# ps-sp            716
# tc               702
# tbs-sct          672
# dfo-mpo          621
# aandc-aadnc      591
# pc               550
# cfia-acia        487
# vac-acc          452
# rcmp-grc         448
# cnsc-ccsn        447
# pwgsc-tpsgc      416
# infc             347
# aafc-aac         329
# ssc-spc          324
# neb-one          261
#                 ...
# vfpa-apvf         16
# atssc-scdata      14
# ocl-cal           13
# cnsopb            12
# mai               12
# wdba-apwd         12
# oci-bec           11
# jccbi-pjcci       11
# cpc-cpp           11
# nserc-crsng       10
# pspib-oirpsp      10
# cca-cac           10
# ...

# %%
acces.disposition.value_counts()
# pas assez clair -> les réponses des demandes sont écrits de manière différente
# Out:
# Disclosed in part / Communication partielle                                                                                      9700
# All disclosed / Communication totale                                                                                             2833
# Disclosed in part                                                                                                                1583
# Disclosed in Part / Communication partielle                                                                                       940
# Disclosed in part / Communication partielle                                                                                       892
# No records exist / Aucun document n'existe                                                                                        849
# All disclosed                                                                                                                     823
# ...

# %%
nb = acces.disposition == "Aucun document"
# allez chercher tous les docs avec « aucun document »
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-e597cc2d3123> in <module>()
# ----> 1 nb = acces.disposition == "Aucun document"
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'disposition'

# %%
acces.disposition.value_counts()/len(acces.disposition) *100
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-82026d7111e7> in <module>()
# ----> 1 acces.disposition.value_counts()/len(acces.disposition) *100
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'disposition'

# %%
acces
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 28462    False
# 28463    False
# 28464    False
# 28465    False
# 28466    False
# 28467    False
# 28468    False
# 28469    False
# 28470    False
# 28471    False
# 28472    False
# 28473    False
# 28474    False
# 28475    False
# 28476    False
# 28477    False
# 28478    False
# 28479    False
# 28480    False
# 28481    False
# 28482    False
# 28483    False
# 28484    False
# 28485    False
# 28486    False
# 28487    False
# 28488    False
# ...

# %%
acces
# Out:
#        year  month request_number  \
# 0      2017      5   A-2016-00059
# 1      2016      7   A-2016-00076
# 2      2016      7   A-2016-00071
# 3      2017      7   A-2017-00063
# 4      2016     10   A-2016-00121
# 5      2016      7   A-2016-00072
# 6      2016      6   A-2016-00026
# 7      2016      7   A-2016-00077
# 8      2016      6   A-2016-00061
# 9      2016      6   A-2016-00038
# 10     2016      6   A-2016-00027
# 11     2016      8   A-2016-00088
# 12     2016      6   A-2016-00024
# 13     2016      6   A-2016-00021
# 14     2016      6   A-2016-00017
# 15     2016      6   A-2016-00014
# 16     2016      6   A-2016-00012
# 17     2016      6   A-2015-00110
# 18     2016      6   A-2015-00104
# 19     2016      6   A-2015-00102
# 20     2016      6   A-2015-00083
# 21     2016      6   A-2014-00158
# 22     2016      6   A-2014-00157
# 23     2016      6   A-2014-00156
# 24     2016      7   A-2016-00082
# 25     2016      7   A-2016-00078
# ...

# %%
acces.columns
# Out:
# Index(['year', 'month', 'request_number', 'summary_en', 'summary_fr',
#        'disposition', 'pages', 'owner_org', 'owner_org_title'],
#       dtype='object')

# %%
acces.columns = ['année', 'mois', 'numéro', 'anglais', 'français',
       'réponse', 'nbpages', 'owner_org', 'owner_titre']
# changer les variables pour que ça soit plus clair

# %%
acces
# Out:
#        année  mois        numéro  \
# 0       2017     5  A-2016-00059
# 1       2016     7  A-2016-00076
# 2       2016     7  A-2016-00071
# 3       2017     7  A-2017-00063
# 4       2016    10  A-2016-00121
# 5       2016     7  A-2016-00072
# 6       2016     6  A-2016-00026
# 7       2016     7  A-2016-00077
# 8       2016     6  A-2016-00061
# 9       2016     6  A-2016-00038
# 10      2016     6  A-2016-00027
# 11      2016     8  A-2016-00088
# 12      2016     6  A-2016-00024
# 13      2016     6  A-2016-00021
# 14      2016     6  A-2016-00017
# 15      2016     6  A-2016-00014
# 16      2016     6  A-2016-00012
# 17      2016     6  A-2015-00110
# 18      2016     6  A-2015-00104
# 19      2016     6  A-2015-00102
# 20      2016     6  A-2015-00083
# 21      2016     6  A-2014-00158
# 22      2016     6  A-2014-00157
# 23      2016     6  A-2014-00156
# 24      2016     7  A-2016-00082
# 25      2016     7  A-2016-00078
# 26      2016     7  A-2016-00075
# ...

# %%
acces.français.value_counts()
# Out:
# Une copie de documents concernant le HMS Terror                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   73
# ...

# %%
acces.réponse
# Out:
# 0        Disclosed in part/\r\nCommunication partielle
# 1          No records exist / Aucun documents existant
# 2          No records exist / Aucun documents existant
# 3        Disclosed in part/\r\nCommunication partielle
# 4            Aucun document existant / No records exit
# 5          No records exist / Aucun documents existant
# 6            No  Records Exist/Aucun document n'existe
# 7          No records exist / Aucun documents existant
# 8            No  Records Exist/Aucun document n'existe
# 9            No  Records Exist/Aucun document n'existe
# 10           No  Records Exist/Aucun document n'existe
# 11         Disclosed in part / Communication partielle
# 12           No  Records Exist/Aucun document n'existe
# 13             Disclosed in part/Divulgation partielle
# 14           No  Records Exist/Aucun document n'existe
# 15             Disclosed in part/Divulgation partielle
# 16             Disclosed in part/Divulgation partielle
# ...

# %%
acces.réponse.value_counts()
# Out:
# Disclosed in part / Communication partielle                                                                                      9700
# All disclosed / Communication totale                                                                                             2833
# Disclosed in part                                                                                                                1583
# Disclosed in Part / Communication partielle                                                                                       940
# Disclosed in part / Communication partielle                                                                                       892
# No records exist / Aucun document n'existe                                                                                        849
# All disclosed                                                                                                                     823
# ...

# %%
acces.groupby("réponse").valeurtotale.sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-b4f7e92da77c> in <module>()
# ----> 1 acces.groupby("réponse").valeurtotale.sum().sort_values(ascending=False)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in __getattr__(self, attr)
#     674
#     675         raise AttributeError("%r object has no attribute %r" %
# --> 676                              (type(self).__name__, attr))
#     677
#     678     plot = property(GroupByPlot)
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'valeurtotale'

# %%
rien = acces.réponse == "Aucun document n’existe"

# %%
rien2 = acces.réponse == "Aucun documents existant"

# %%
rien3 = acces.réponse == "Aucun documents existant"

# %%
rien4 = acces.réponse == "Aucun document existe"

# %%
rien5 = acces.réponse == "Aucun document"

# %%
rien6 = acces.réponse == "Aucun documents"

# %%
rien7 = acces.réponse == "Aucun documents existe"
# créer une variable pour chaque formulation, n'a pas marché

# %%
acces[rien]
# Out:
#       année  mois    numéro  \
# 4665   2016     6  A-084889
# 4679   2016     7  A-086264
#
#                                                 anglais  \
# 4665  Info prepared for and by the Canada Revenue Ag...
# 4679  All documents relating to discussions with the...
#
#                                                français  \
# 4665  Les renseignements préparés par le Conseil de ...
# 4679  Tous les documents liés aux discussions avec l...
#
#                       réponse  nbpages owner_org  \
# 4665  Aucun document n’existe     0.00   cra-arc
# 4679  Aucun document n’existe     0.00   cra-arc
#
#                                             owner_titre
# 4665  Canada Revenue Agency | Agence du revenu du Ca...
# 4679  Canada Revenue Agency | Agence du revenu du Ca...

# %%
acces[rien2]
# Out:
# Empty DataFrame
# Columns: [année, mois, numéro, anglais, français, réponse, nbpages, owner_org, owner_titre]
# Index: []

# %%
acces[rien3]
# Out:
# Empty DataFrame
# Columns: [année, mois, numéro, anglais, français, réponse, nbpages, owner_org, owner_titre]
# Index: []

# %%
pasgrandchose = acces.réponse.str.contains("Aucun")

# %%
acces[pasgrandchose]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-2d1dd0dc2b58> in <module>()
# ----> 1 acces[pasgrandchose]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2158     def _getitem_array(self, key):
#    2159         # also raises Exception if object array with NA values
# -> 2160         if com.is_bool_indexer(key):
#    2161             # warning here just in case -- previously __setitem__ was
# ...

# %%
aucunerep = ~acces.réponse.str.contains("Aucun")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-941621753a2c> in <module>()
# ----> 1 aucunerep = ~acces.réponse.str.contains("Aucun")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __invert__(self)
#    1019     def __invert__(self):
#    1020         try:
# -> 1021             arr = operator.inv(_values_from_object(self))
#    1022             return self.__array_wrap__(arr)
#    1023         except:
#
# TypeError: bad operand type for unary ~: 'float'

# %%
acces.année.value_counts().plot(kind="bar")
# créer un tableau par année

# %%
# ce que j'aurais aimé davantage faire. Trouver comment cibler le mot « aucun » et ensuite le lier à la variable « owmenr » pour savoir les ministères les moins ouverts ou qui caviardent le plus.
